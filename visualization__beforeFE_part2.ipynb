# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Load RAW data (before feature engineering)
mob_df = pd.read_csv("./data/yjmob100k-dataset1.csv.gz")
grid_df = pd.read_csv("./data/cell_POIcat.csv.gz")
poi_map = pd.read_csv("./data/POI_datacategories.csv", header=None)

print(f"Mobility data shape: {mob_df.shape}")
print(f"Grid data shape: {grid_df.shape}")
print(f"\nMobility columns: {mob_df.columns.tolist()}")
print(f"\nFirst few rows:\n{mob_df.head()}")
# Out:
# Mobility data shape: (111535175, 5)
# Grid data shape: (221159, 4)
#
# Mobility columns: ['uid', 'd', 't', 'x', 'y']
#
# First few rows:
#    uid  d   t   x   y
# 0    0  0   1  79  86
# 1    0  0   2  79  86
# 2    0  0   8  77  86
# 3    0  0   9  77  86
# 4    0  0  19  81  89

# %%
# ============================================
# 1. TEMPORAL FEATURES VALIDATION
# ============================================

fig, axes = plt.subplots(2, 2, figsize=(18, 10))

# 1a: Day of week patterns (validates is_weekend feature)
mob_df['day_of_week'] = mob_df['d'] % 7
dow_activity = mob_df.groupby('day_of_week').size()

dow_labels = ['Sun', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat']
colors = ['#e74c3c' if i in [0, 6] else '#3498db' for i in range(7)]
axes[0, 0].bar(range(7), dow_activity.values, color=colors, alpha=0.7)
axes[0, 0].set_xlabel('Day of Week', fontsize=11, fontweight='bold')
axes[0, 0].set_ylabel('Number of Records', fontsize=11, fontweight='bold')
axes[0, 0].set_title('Activity Distribution by Day of Week', 
                     fontsize=12, fontweight='bold')
axes[0, 0].set_xticks(range(7))
axes[0, 0].set_xticklabels(dow_labels, rotation=0)
axes[0, 0].grid(alpha=0.3, axis='y')


# 1b: Intra-day movement pattern (validates activity periods)
mob_df['timeslot'] = mob_df['t']
mob_df['hour'] = mob_df['t'] // 2
hourly_activity = mob_df.groupby('hour').size()

# Count unique locations per user per timeslot
movement_by_time = mob_df.groupby('timeslot').apply(
    lambda x: x.groupby('uid')[['x', 'y']].apply(lambda g: len(g.drop_duplicates()))
).reset_index()
movement_by_time.columns = ['timeslot', 'uid', 'unique_locs']
avg_movement = movement_by_time.groupby('timeslot')['unique_locs'].mean()

axes[0, 1].plot(avg_movement.index, avg_movement.values, linewidth=2, color='purple')
axes[0, 1].fill_between(avg_movement.index, avg_movement.values, alpha=0.3, color='purple')
axes[0, 1].set_xlabel('30-min Time Slot', fontsize=11, fontweight='bold')
axes[0, 1].set_ylabel('Avg Unique Locations per User', fontsize=11, fontweight='bold')
axes[0, 1].set_title('Movement Diversity Throughout Day', 
                     fontsize=12, fontweight='bold')
axes[0, 1].axvspan(0, 10, alpha=0.2, color='gray', label='Night (rest)')
axes[0, 1].axvspan(14, 18, alpha=0.2, color='yellow', label='Morning commute')
axes[0, 1].axvspan(34, 40, alpha=0.2, color='orange', label='Evening commute')
axes[0, 1].legend(loc = 'upper right')
axes[0, 1].grid(alpha=0.3)

# 1c: Holiday effect check
holiday_list = [0, 1, 6, 7, 8, 13, 14, 20, 21, 27, 28, 29, 34, 35, 37, 41, 42, 
                48, 49, 50, 55, 56, 62, 63, 69, 70] # Example holiday days
mob_df['is_holiday'] = mob_df['d'].isin(holiday_list).astype(int)
holiday_comparison = mob_df.groupby(['is_holiday', 'hour']).size().unstack(fill_value=0)

axes[1, 0].plot(holiday_comparison.columns, holiday_comparison.loc[0], 
                'b-', linewidth=2, label='Regular Days', marker='o')
axes[1, 0].plot(holiday_comparison.columns, holiday_comparison.loc[1], 
                'r--', linewidth=2, label='Holidays', marker='s')
axes[1, 0].set_xlabel('Hour of Day', fontsize=11, fontweight='bold')
axes[1, 0].set_ylabel('Total Records', fontsize=11, fontweight='bold')
axes[1, 0].set_title('Activity Pattern: Holidays vs Regular Days', 
                     fontsize=12, fontweight='bold')
axes[1, 0].legend()
axes[1, 0].grid(alpha=0.3)

# 1d: Temporal variance by user
user_variance = mob_df.groupby('uid')['t'].agg(['std', 'count']).reset_index()
user_variance = user_variance[user_variance['count'] > 50]  # Only consider users with >50 records for reliability

axes[1, 1].hist(user_variance['std'], bins=50, color='coral', edgecolor='black', alpha=0.7)
axes[1, 1].set_xlabel('Std Dev of Time Slots', fontsize=11, fontweight='bold')
axes[1, 1].set_ylabel('Number of Users', fontsize=11, fontweight='bold')
axes[1, 1].set_title('Temporal Consistency Across Users\n(High variance = diverse routines)', 
                     fontsize=12, fontweight='bold')
axes[1, 1].axvline(user_variance['std'].mean(), color='red', linestyle='--', 
                   linewidth=2, label=f'Mean: {user_variance["std"].mean():.1f}')
axes[1, 1].legend()
axes[1, 1].grid(alpha=0.3, axis='y')

plt.tight_layout()
plt.savefig('figures/temporal_validation.png', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# C:\Users\moham\AppData\Local\Temp\ipykernel_23128\185873536.py:30: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   movement_by_time = mob_df.groupby('timeslot').apply(

# %%
# ============================================
# 2. SPATIAL FEATURES VALIDATION
# ============================================
print("\n" + "="*60)
print("SPATIAL FEATURES - Do location patterns exist?")
print("="*60)

fig, axes = plt.subplots(2, 2, figsize=(18, 10))

# 2a: Spatial distribution (validates need for POI density)
grid_poi_density = grid_df.groupby(['x', 'y'])['POI_count'].sum().reset_index()

scatter = axes[0, 0].scatter(grid_poi_density['x'], grid_poi_density['y'], 
                             c=grid_poi_density['POI_count'], cmap='YlOrRd', 
                             s=20, alpha=0.6)
axes[0, 0].set_xlabel('X Coordinate', fontsize=11, fontweight='bold')
axes[0, 0].set_ylabel('Y Coordinate', fontsize=11, fontweight='bold')
axes[0, 0].set_title('POI Density Spatial Distribution\n(Shows spatial heterogeneity)', 
                     fontsize=12, fontweight='bold')
plt.colorbar(scatter, ax=axes[0, 0], label='POI Count')
axes[0, 0].set_aspect('equal')

# 2b: POI density distribution (validates log transformation need)
axes[0, 1].hist(grid_poi_density['POI_count'], bins=50, color='green', 
                edgecolor='black', alpha=0.7)
axes[0, 1].set_xlabel('POI Count per Grid Cell', fontsize=11, fontweight='bold')
axes[0, 1].set_ylabel('Frequency', fontsize=11, fontweight='bold')
axes[0, 1].set_title('POI Density Distribution\n(Check if log transform needed)', 
                     fontsize=12, fontweight='bold')
axes[0, 1].set_yscale('log')
axes[0, 1].axvline(grid_poi_density['POI_count'].median(), color='red', 
                   linestyle='--', linewidth=2, 
                   label=f'Median: {grid_poi_density["POI_count"].median():.0f}')
axes[0, 1].legend()
axes[0, 1].grid(alpha=0.3)

# 2c: POI category diversity (validates need for LDA/topic modeling)
poi_diversity = grid_df.groupby(['x', 'y'])['POIcategory'].nunique().reset_index()
poi_diversity.columns = ['x', 'y', 'num_categories']

axes[0, 2].hist(poi_diversity['num_categories'], bins=range(1, poi_diversity['num_categories'].max()+2), 
                color='purple', edgecolor='black', alpha=0.7, align='left')
axes[0, 2].set_xlabel('Number of POI Categories per Cell', fontsize=11, fontweight='bold')
axes[0, 2].set_ylabel('Number of Cells', fontsize=11, fontweight='bold')
axes[0, 2].set_title('POI Category Diversity\n(High diversity → need topic modeling)', 
                     fontsize=12, fontweight='bold')
axes[0, 2].axvline(poi_diversity['num_categories'].mean(), color='red', 
                   linestyle='--', linewidth=2, 
                   label=f'Mean: {poi_diversity["num_categories"].mean():.1f}')
axes[0, 2].legend()
axes[0, 2].grid(alpha=0.3, axis='y')

# 2d: Movement range per user (validates radius of gyration feature)
user_locations = mob_df.groupby('uid').agg({
    'x': lambda x: x.max() - x.min(),
    'y': lambda y: y.max() - y.min()
}).reset_index()
user_locations['spatial_range'] = np.sqrt(user_locations['x']**2 + user_locations['y']**2)

axes[1, 0].hist(user_locations['spatial_range'], bins=50, color='teal', 
                edgecolor='black', alpha=0.7)
axes[1, 0].set_xlabel('Spatial Range (grid cells)', fontsize=11, fontweight='bold')
axes[1, 0].set_ylabel('Number of Users', fontsize=11, fontweight='bold')
axes[1, 0].set_title('User Movement Range Distribution\n(Validates radius of gyration)', 
                     fontsize=12, fontweight='bold')
axes[1, 0].axvline(user_locations['spatial_range'].median(), color='red', 
                   linestyle='--', linewidth=2, 
                   label=f'Median: {user_locations["spatial_range"].median():.1f}')
axes[1, 0].legend()
axes[1, 0].set_yscale('log')
axes[1, 0].grid(alpha=0.3)

# 2e: Location revisit frequency (validates home detection logic)
location_visits = mob_df.groupby(['uid', 'x', 'y']).size().reset_index(name='visits')
user_max_visits = location_visits.groupby('uid')['visits'].max().reset_index()

axes[1, 1].hist(user_max_visits['visits'], bins=50, color='orange', 
                edgecolor='black', alpha=0.7)
axes[1, 1].set_xlabel('Max Visits to Any Single Location', fontsize=11, fontweight='bold')
axes[1, 1].set_ylabel('Number of Users', fontsize=11, fontweight='bold')
axes[1, 1].set_title('Location Revisit Patterns\n(High values → clear anchor points)', 
                     fontsize=12, fontweight='bold')
axes[1, 1].set_yscale('log')
axes[1, 1].axvline(user_max_visits['visits'].median(), color='red', 
                   linestyle='--', linewidth=2, 
                   label=f'Median: {user_max_visits["visits"].median():.0f}')
axes[1, 1].legend()
axes[1, 1].grid(alpha=0.3)

# 2f: Number of unique locations per user (validates exploratory behavior)
unique_locs = mob_df.groupby('uid').apply(
    lambda x: len(x[['x', 'y']].drop_duplicates())
).reset_index(name='unique_locations')

axes[1, 2].hist(unique_locs['unique_locations'], bins=50, color='crimson', 
                edgecolor='black', alpha=0.7)
axes[1, 2].set_xlabel('Unique Locations Visited', fontsize=11, fontweight='bold')
axes[1, 2].set_ylabel('Number of Users', fontsize=11, fontweight='bold')
axes[1, 2].set_title('Spatial Exploration per User\n(Validates need for exploration features)', 
                     fontsize=12, fontweight='bold')
axes[1, 2].axvline(unique_locs['unique_locations'].median(), color='red', 
                   linestyle='--', linewidth=2, 
                   label=f'Median: {unique_locs["unique_locations"].median():.0f}')
axes[1, 2].legend()
axes[1, 2].grid(alpha=0.3, axis='y')

plt.tight_layout()
plt.savefig('pre_fe_spatial_validation.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# ============================================
# 3. BEHAVIORAL FEATURES VALIDATION
# ============================================
print("\n" + "="*60)
print("BEHAVIORAL FEATURES - Do movement patterns exist?")
print("="*60)

fig, axes = plt.subplots(2, 2, figsize=(18, 10))

# 3a: Sequential location changes (validates state transition features)
mob_df_sorted = mob_df.sort_values(['uid', 'd', 't'])
mob_df_sorted['loc_id'] = mob_df_sorted['x'].astype(str) + "_" + mob_df_sorted['y'].astype(str)
mob_df_sorted['loc_changed'] = (
    mob_df_sorted.groupby('uid')['loc_id'].shift() != mob_df_sorted['loc_id']
).astype(int)

change_rate = mob_df_sorted.groupby('uid')['loc_changed'].mean().reset_index()

axes[0, 0].hist(change_rate['loc_changed'], bins=50, color='indigo', 
                edgecolor='black', alpha=0.7)
axes[0, 0].set_xlabel('Location Change Rate', fontsize=11, fontweight='bold')
axes[0, 0].set_ylabel('Number of Users', fontsize=11, fontweight='bold')
axes[0, 0].set_title('Movement Frequency per User\n(High = mobile, Low = stationary)', 
                     fontsize=12, fontweight='bold')
axes[0, 0].axvline(change_rate['loc_changed'].mean(), color='red', 
                   linestyle='--', linewidth=2, 
                   label=f'Mean: {change_rate["loc_changed"].mean():.2f}')
axes[0, 0].legend()
axes[0, 0].grid(alpha=0.3, axis='y')

# 3b: Return-to-home patterns (validates motif detection)
# Simple proxy: nighttime location consistency
night_records = mob_df[mob_df['t'] < 12]  # Before 6am
night_stability = night_records.groupby('uid').apply(
    lambda x: len(x[['x', 'y']].drop_duplicates()) / len(x) if len(x) > 0 else np.nan
).reset_index(name='night_diversity')

axes[0, 1].hist(night_stability['night_diversity'].dropna(), bins=50, 
                color='navy', edgecolor='black', alpha=0.7)
axes[0, 1].set_xlabel('Nighttime Location Diversity', fontsize=11, fontweight='bold')
axes[0, 1].set_ylabel('Number of Users', fontsize=11, fontweight='bold')
axes[0, 1].set_title('Home Stability Score\n(Low = consistent home location)', 
                     fontsize=12, fontweight='bold')
axes[0, 1].axvline(night_stability['night_diversity'].median(), color='red', 
                   linestyle='--', linewidth=2, 
                   label=f'Median: {night_stability["night_diversity"].median():.3f}')
axes[0, 1].legend()
axes[0, 1].grid(alpha=0.3, axis='y')

# 3c: Daily trip complexity (validates motif classification)
# Count location changes per day
daily_transitions = mob_df_sorted.groupby(['uid', 'd'])['loc_changed'].sum().reset_index()
transitions_dist = daily_transitions.groupby('loc_changed').size()

axes[0, 2].bar(transitions_dist.index[:20], transitions_dist.values[:20], 
               color='darkgreen', alpha=0.7)
axes[0, 2].set_xlabel('Number of Location Changes per Day', fontsize=11, fontweight='bold')
axes[0, 2].set_ylabel('Frequency', fontsize=11, fontweight='bold')
axes[0, 2].set_title('Daily Movement Complexity\n(Validates motif rules)', 
                     fontsize=12, fontweight='bold')
axes[0, 2].set_yscale('log')
axes[0, 2].grid(alpha=0.3, axis='y')

# 3d: User consistency over time (validates person type features)
user_daily_locs = mob_df.groupby(['uid', 'd']).apply(
    lambda x: len(x[['x', 'y']].drop_duplicates())
).reset_index(name='daily_locs')
user_consistency = user_daily_locs.groupby('uid')['daily_locs'].std().reset_index()

axes[1, 0].hist(user_consistency['daily_locs'].dropna(), bins=50, 
                color='brown', edgecolor='black', alpha=0.7)
axes[1, 0].set_xlabel('Std Dev of Daily Locations', fontsize=11, fontweight='bold')
axes[1, 0].set_ylabel('Number of Users', fontsize=11, fontweight='bold')
axes[1, 0].set_title('User Routine Consistency\n(Low = predictable, High = variable)', 
                     fontsize=12, fontweight='bold')
axes[1, 0].axvline(user_consistency['daily_locs'].median(), color='red', 
                   linestyle='--', linewidth=2, 
                   label=f'Median: {user_consistency["daily_locs"].median():.1f}')
axes[1, 0].legend()
axes[1, 0].grid(alpha=0.3, axis='y')

# 3e: Stop duration patterns (validates dwell time features)
# Approximate by counting consecutive same-location records
mob_df_sorted['same_loc'] = (~mob_df_sorted['loc_changed']).astype(int)
mob_df_sorted['stop_id'] = (mob_df_sorted['loc_changed'] == 1).cumsum()

stop_durations = mob_df_sorted.groupby(['uid', 'stop_id']).size().reset_index(name='duration')
stop_durations = stop_durations[stop_durations['duration'] > 1]  # Filter out instant stops

axes[1, 1].hist(stop_durations['duration'], bins=50, range=(0, 50), 
                color='olive', edgecolor='black', alpha=0.7)
axes[1, 1].set_xlabel('Stop Duration (30-min slots)', fontsize=11, fontweight='bold')
axes[1, 1].set_ylabel('Frequency', fontsize=11, fontweight='bold')
axes[1, 1].set_title('Stop Duration Distribution\n(Validates dwell time features)', 
                     fontsize=12, fontweight='bold')
axes[1, 1].set_yscale('log')
axes[1, 1].axvline(stop_durations['duration'].median(), color='red', 
                   linestyle='--', linewidth=2, 
                   label=f'Median: {stop_durations["duration"].median():.0f}')
axes[1, 1].legend()
axes[1, 1].grid(alpha=0.3, axis='y')

# 3f: Weekday vs weekend behavior difference (validates context-aware features)
weekday_locs = mob_df[~mob_df['day_of_week'].isin([0, 6])].groupby('uid').apply(
    lambda x: len(x[['x', 'y']].drop_duplicates())
).reset_index(name='weekday_locs')

weekend_locs = mob_df[mob_df['day_of_week'].isin([0, 6])].groupby('uid').apply(
    lambda x: len(x[['x', 'y']].drop_duplicates())
).reset_index(name='weekend_locs')

behavior_diff = weekday_locs.merge(weekend_locs, on='uid', how='inner')
behavior_diff['difference'] = behavior_diff['weekend_locs'] - behavior_diff['weekday_locs']

axes[1, 2].hist(behavior_diff['difference'], bins=50, 
                color='magenta', edgecolor='black', alpha=0.7)
axes[1, 2].set_xlabel('Weekend - Weekday Unique Locations', fontsize=11, fontweight='bold')
axes[1, 2].set_ylabel('Number of Users', fontsize=11, fontweight='bold')
axes[1, 2].set_title('Weekend vs Weekday Behavior\n(Non-zero = context matters)', 
                     fontsize=12, fontweight='bold')
axes[1, 2].axvline(0, color='black', linestyle='-', linewidth=1)
axes[1, 2].axvline(behavior_diff['difference'].mean(), color='red', 
                   linestyle='--', linewidth=2, 
                   label=f'Mean: {behavior_diff["difference"].mean():.1f}')
axes[1, 2].legend()
axes[1, 2].grid(alpha=0.3, axis='y')

plt.tight_layout()
plt.savefig('pre_fe_behavioral_validation.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# ============================================
# SUMMARY REPORT
# ============================================
print("\n" + "="*80)
print("FEATURE ENGINEERING VALIDATION SUMMARY")
print("="*80)

print("\n1. TEMPORAL FEATURES:")
print(f"   ✓ Hourly patterns detected: {hourly_activity.std():.1f} std dev")
print(f"   ✓ Weekend effect: {(dow_activity[0] - dow_activity[1]) / dow_activity[1] * 100:.1f}% difference")
print(f"   ✓ Holiday effect: {mob_df.groupby('is_holiday').size().to_dict()}")
print(f"   → RECOMMENDED: activity_period, is_weekend, is_holiday, time_delta")

print("\n2. SPATIAL FEATURES:")
print(f"   ✓ POI density range: {grid_poi_density['POI_count'].min()}-{grid_poi_density['POI_count'].max()}")
print(f"   ✓ POI diversity: {poi_diversity['num_categories'].mean():.1f} avg categories/cell")
print(f"   ✓ Median movement range: {user_locations['spatial_range'].median():.1f} cells")
print(f"   → RECOMMENDED: poi_density, LDA topics, radius_of_gyration")

print("\n3. BEHAVIORAL FEATURES:")
print(f"   ✓ Avg location change rate: {change_rate['loc_changed'].mean():.2f}")
print(f"   ✓ Nighttime stability: {(night_stability['night_diversity'] < 0.1).sum() / len(night_stability) * 100:.1f}% have stable home")
print(f"   ✓ Median daily transitions: {daily_transitions['loc_changed'].median():.0f}")
print(f"   → RECOMMENDED: motif_id, state (H/T), stop_duration, routine_consistency")

print("\n" + "="*80)
print("NEXT STEPS:")
print("="*80)
print("1. If temporal patterns are WEAK → Don't over-engineer time features")
print("2. If spatial heterogeneity is LOW → Simpler spatial features suffice")
print("3. If behavioral variance is HIGH → Invest in person-type clustering")
print("="*80)
